# %% [markdown]
# # Pandas

# %% [markdown]
# ## Basic Function

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ["A","B","C"], index = ["x","y","z"])

# %%
df.head(2) #head takes out element from the top
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6

# %%
df.tail(2) # tail takes out element from the bottom
# Out:
#    A  B  C
# y  4  5  6
# z  7  8  9

# %%
df.columns # gives number of columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index # gives number of rows
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.info() # gives information about the table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe() # give statistical information
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape # gives shape of the dataframe
# Out:
# (3, 3)

# %%
df.size # total number of elements inside the dataframe
# Out:
# 9

# %%
coffee = pd.read_csv("../datasets/coffee.csv")
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## Accessing Data

# %%
coffee.sample(7) #gives random datapoints from datframe
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 10   Saturday    Espresso          45
# 5   Wednesday       Latte          25
# 12     Sunday    Espresso          45
# 8      Friday    Espresso          45
# 6    Thursday    Espresso          40

# %%
coffee.loc[5:13,['Day','Units Sold']] # not compulsorily numeric
# Out:
#           Day  Units Sold
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.iloc[5:13,0:2] # requires only numeric datapoints
# Out:
#           Day Coffee Type
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso

# %%
coffee.loc[2,'Units Sold'] = 10
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.at[0,'Day'] # a specific index retrival
# Out:
# 'Monday'

# %%
coffee.iat[0,0] # only accepts integer
# Out:
# 'Monday'

# %% [markdown]
# ## Sorting data

# %%
coffee.sort_values("Units Sold", ascending=False) # sort the column
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          10

# %%
coffee.sort_values(['Units Sold','Coffee Type'], ascending = [1,0]) #sort multiple columns in grouped columned
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %% [markdown]
# ## Filtering Data

# %%
bios = pd.read_csv('../datasets/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
tall_and_usa = bios.loc[(bios['height_cm'] > 215) & (bios['born_country']=='USA'), ['name','height_cm']]

# %%
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]
vowel_cities
# Out:
#         athlete_id                     name   born_date       born_city  \
# 5                6        Nicolas Chatelain  1970-01-13          Amiens
# 10              11  Élie, Comte de Lastours  1874-08-12         Orgeval
# 17              18     Jean-Philippe Gatien  1968-10-16            Alès
# 35              36          Étienne Thobois  1967-09-20          Amiens
# 40              41           Julie Bradbury  1967-02-12          Oxford
# ...            ...                      ...         ...             ...
# 145395      149118             Abbey Murphy  2002-04-14  Evergreen Park
# 145398      149121          Grace Zumwinkle  1999-04-23       Excelsior
# 145405      149128             Brian Cooper  1993-11-01       Anchorage
# 145418      149141              Nick Perbix  1998-06-15       Elk River
# 145427      149150            Jared Shumate  1999-03-06         Atlanta
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# 5            Somme          FRA         France      181.0       70.0
# 10        Yvelines          FRA         France        NaN        NaN
# 17            Gard          FRA         France      178.0       73.0
# 35           Somme          FRA         France      186.0       78.0
# 40         England          GBR  Great Britain      175.0       64.0
# ...            ...          ...            ...        ...        ...
# 145395    Illinois          USA  United States        NaN        NaN
# 145398   Minnesota          USA  United States        NaN        NaN
# 145405      Alaska          USA  United States        NaN        NaN
# 145418   Minnesota          USA  United States        NaN        NaN
# 145427     Georgia          USA  United States        NaN        NaN
#
#          died_date
# 5              NaN
# 10      1932-11-18
# 17             NaN
# 35             NaN
# 40             NaN
# ...            ...
# 145395         NaN
# 145398         NaN
# 145405         NaN
# 145418         NaN
# 145427         NaN
#
# [12968 rows x 10 columns]

# %%
bios.query('born_country == "FRA"')
# Out:
#         athlete_id                   name   born_date    born_city  \
# 0                1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01       Meulan
# 2                3           Jean Borotra  1898-08-13     Biarritz
# 3                4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13       Amiens
# ...            ...                    ...         ...          ...
# 144652      148348          James Clugnet  1996-12-04     Grenoble
# 145009      148720        Margaux Hackett  1999-06-02       Annecy
# 145281      149002         Elliott Baralo  1998-08-01       Annecy
# 145467      149194            Elisa Nakab  1998-05-08     Briançon
# 145498      149225         André Foussard  1899-05-19        Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# 1                   Yvelines          FRA         France      183.0
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 3                      Paris          FRA         France      168.0
# 5                      Somme          FRA         France      181.0
# ...                      ...          ...            ...        ...
# 144652                 Isère          FRA  Great Britain        NaN
# 145009          Haute-Savoie          FRA    New Zealand        NaN
# 145281          Haute-Savoie          FRA         Sweden        NaN
# 145467          Hautes-Alpes          FRA          Italy        NaN
# 145498           Deux-Sèvres          FRA         France      166.0
#
#         weight_kg   died_date
# 0             NaN  1960-10-02
# 1            76.0         NaN
# 2            76.0  1994-07-17
# 3            64.0  1978-03-20
# 5            70.0         NaN
# ...           ...         ...
# 144652        NaN         NaN
# 145009        NaN         NaN
# 145281        NaN         NaN
# 145467        NaN         NaN
# 145498        NaN  1986-03-18
#
# [5143 rows x 10 columns]

# %% [markdown]
# ## Adding and Removing Columns

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
import numpy as np
coffee['new_price'] = np.where(coffee['Coffee Type']=='Espresso',3.99,5.99)
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          10       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold  new_price
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          10       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee['old_price'] = 4.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  old_price
# 0      Monday    Espresso          25       3.99       4.99
# 1      Monday       Latte          15       5.99       4.99
# 2     Tuesday    Espresso          10       3.99       4.99
# 3     Tuesday       Latte          20       5.99       4.99
# 4   Wednesday    Espresso          35       3.99       4.99
# 5   Wednesday       Latte          25       5.99       4.99
# 6    Thursday    Espresso          40       3.99       4.99
# 7    Thursday       Latte          30       5.99       4.99
# 8      Friday    Espresso          45       3.99       4.99
# 9      Friday       Latte          35       5.99       4.99
# 10   Saturday    Espresso          45       3.99       4.99
# 11   Saturday       Latte          35       5.99       4.99
# 12     Sunday    Espresso          45       3.99       4.99
# 13     Sunday       Latte          35       5.99       4.99

# %%
coffee.drop(columns=['old_price'], inplace = True)
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          10       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee['revenue'] = coffee['Units Sold']*coffee['new_price']
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          10       3.99    39.90
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price':'price'}, inplace = True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          10   3.99    39.90
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
bios['born_datetime'] = pd.to_datetime(bios['born_date'])
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date born_datetime
# 145495         NaN    2002-01-30
# 145496         NaN    1999-09-20
# 145497         NaN    1998-05-08
# 145498  1986-03-18    1899-05-19
# 145499  2003-10-20    1913-07-15

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 12.2+ MB

# %%
bios['born_year'] = bios['born_datetime'].dt.year
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date born_datetime  born_year
# 145495         NaN    2002-01-30     2002.0
# 145496         NaN    1999-09-20     1999.0
# 145497         NaN    1998-05-08     1998.0
# 145498  1986-03-18    1899-05-19     1899.0
# 145499  2003-10-20    1913-07-15     1913.0

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x : 'short' if x < 165 else ('Average' if x < 185 else 'Tall'))
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date born_datetime  born_year height_category
# 0  1960-10-02    1886-12-12     1886.0            Tall
# 1         NaN    1969-04-01     1969.0         Average
# 2  1994-07-17    1898-08-13     1898.0         Average
# 3  1978-03-20    1895-05-11     1895.0         Average
# 4  1930-07-25    1878-04-17     1878.0            Tall

# %% [markdown]
# ## Merging And Concatenating Data

# %%
nocs = pd.read_csv('../datasets/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date born_datetime  born_year height_category
# 0  1960-10-02    1886-12-12     1886.0            Tall
# 1         NaN    1969-04-01     1969.0         Average
# 2  1994-07-17    1898-08-13     1898.0         Average
# 3  1978-03-20    1895-05-11     1895.0         Average
# 4  1930-07-25    1878-04-17     1878.0            Tall

# %%
bios = pd.merge(bios,nocs, left_on = 'born_country', right_on='NOC', how='left')
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country      NOC_x  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date born_datetime  born_year height_category NOC_y     region  \
# 145495         NaN    2002-01-30     2002.0         Average   RUS     Russia
# 145496         NaN    1999-09-20     1999.0         Average   RUS     Russia
# 145497         NaN    1998-05-08     1998.0           short   RUS     Russia
# 145498  1986-03-18    1899-05-19     1899.0         Average   FRA     France
# 145499  2003-10-20    1913-07-15     1913.0            Tall   AUS  Australia
#
#        notes
# 145495   NaN
# 145496   NaN
# 145497   NaN
# 145498   NaN
# 145499   NaN

# %%
bios[bios['NOC_x'] != bios['region']][['name','NOC_x','region']].head()
# Out:
#                   name   NOC_x   region
# 4         Albert Canet  France       UK
# 12           J. Defert  France      NaN
# 13      Étienne Durand  France      NaN
# 16          Guy Forget  France  Morocco
# 27  Guy, Baron Lejeune  France      NaN

# %%
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR'].copy()

# %%
usa.tail()
# Out:
#         athlete_id               name   born_date      born_city  born_region  \
# 145445      149168     Kristen Santos  1994-11-02      Fairfield  Connecticut
# 145446      149169   Corinne Stoddard  2001-08-15        Seattle   Washington
# 145454      149180      Anna Hoffmann  2000-03-28        Madison    Wisconsin
# 145457      149183     Alix Wilkinson  2000-08-02  Mammoth Lakes   California
# 145468      149195  Justin Abdelkader  1987-02-25       Muskegon     Michigan
#
#        born_country          NOC_x  height_cm  weight_kg died_date  \
# 145445          USA  United States        NaN        NaN       NaN
# 145446          USA  United States        NaN        NaN       NaN
# 145454          USA  United States        NaN        NaN       NaN
# 145457          USA  United States        NaN        NaN       NaN
# 145468          USA  United States      187.0       97.0       NaN
#
#        born_datetime  born_year height_category NOC_y region notes
# 145445    1994-11-02     1994.0            Tall   USA    USA   NaN
# 145446    2001-08-15     2001.0            Tall   USA    USA   NaN
# 145454    2000-03-28     2000.0            Tall   USA    USA   NaN
# 145457    2000-08-02     2000.0            Tall   USA    USA   NaN
# 145468    1987-02-25     1987.0            Tall   USA    USA   NaN

# %%
gbr.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                NOC_x  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        born_datetime  born_year height_category NOC_y region notes
# 144811    1983-05-08     1983.0            Tall   GBR     UK   NaN
# 144815    1993-10-28     1993.0            Tall   GBR     UK   NaN
# 145005    2001-08-13     2001.0         Average   GBR     UK   NaN
# 145319    1992-04-02     1992.0            Tall   GBR     UK   NaN
# 145388    1993-10-07     1993.0            Tall   GBR     UK   NaN

# %%
new_bios = pd.concat([usa,gbr])
new_bios.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country          NOC_x  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      born_datetime  born_year height_category NOC_y region notes
# 54      1967-07-22     1967.0         Average   USA    USA   NaN
# 960     1968-09-17     1968.0         Average   USA    USA   NaN
# 961     1973-10-03     1973.0           short   USA    USA   NaN
# 1231    1897-07-01     1897.0            Tall   USA    USA   NaN
# 1345    1975-01-06     1975.0         Average   USA    USA   NaN

# %%
results = pd.read_csv('../datasets/results.csv')
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')
combined_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied  ...   NOC_x height_cm  \
# 0           1  FRA              NaN   17.0   True  ...  France       NaN
# 1           1  FRA   Jean Montariol    NaN  False  ...  France       NaN
# 2           1  FRA              NaN   32.0   True  ...  France       NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True  ...  France       NaN
# 4           1  FRA  Jacques Brugnon    4.0  False  ...  France       NaN
#
#   weight_kg   died_date born_datetime born_year height_category  NOC_y  \
# 0       NaN  1960-10-02    1886-12-12    1886.0            Tall    FRA
# 1       NaN  1960-10-02    1886-12-12    1886.0            Tall    FRA
# 2       NaN  1960-10-02    1886-12-12    1886.0            Tall    FRA
# 3       NaN  1960-10-02    1886-12-12    1886.0            Tall    FRA
# 4       NaN  1960-10-02    1886-12-12    1886.0            Tall    FRA
#
#    region notes
# 0  France   NaN
# 1  France   NaN
# 2  France   NaN
# 3  France   NaN
# 4  France   NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Handling Null Values

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results.isna().sum()
# Out:
# year            2601
# type            2601
# discipline         1
# event              0
# as                 0
# athlete_id         0
# noc                1
# team          186694
# place          25215
# tied               0
# medal         264269
# dtype: int64

# %%
results['year'].isna().sum()
# Out:
# 2601

# %%
results['year'] = results['year'].fillna(results['year'].mean())
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
#  3   price        14 non-null     float64
#  4   revenue      14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 692.0+ bytes

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso          25   3.99    99.75
# 1     Monday       Latte          15   5.99    89.85
# 2    Tuesday    Espresso          10   3.99    39.90
# 3    Tuesday       Latte          20   5.99   119.80
# 4  Wednesday    Espresso          35   3.99   139.65

# %%
coffee.loc[[3,4],'Units Sold'] = np.NaN
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso        25.0   3.99    99.75
# 1     Monday       Latte        15.0   5.99    89.85
# 2    Tuesday    Espresso        10.0   3.99    39.90
# 3    Tuesday       Latte         NaN   5.99   119.80
# 4  Wednesday    Espresso         NaN   3.99   139.65

# %%
coffee['Units Sold'] = coffee['Units Sold'].interpolate()
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso        25.0   3.99    99.75
# 1     Monday       Latte        15.0   5.99    89.85
# 2    Tuesday    Espresso        10.0   3.99    39.90
# 3    Tuesday       Latte        15.0   5.99   119.80
# 4  Wednesday    Espresso        20.0   3.99   139.65

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        308408 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results.dropna(subset = ['type'], inplace= True)

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305807 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  305806 non-null  object
#  3   event       305807 non-null  object
#  4   as          305807 non-null  object
#  5   athlete_id  305807 non-null  int64
#  6   noc         305806 non-null  object
#  7   team        120830 non-null  object
#  8   place       281519 non-null  float64
#  9   tied        305807 non-null  bool
#  10  medal       43645 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 26.0+ MB

# %% [markdown]
# ## Aggregating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date born_datetime  born_year height_category NOC_y  region notes
# 0  1960-10-02    1886-12-12     1886.0            Tall   FRA  France   NaN
# 1         NaN    1969-04-01     1969.0         Average   FRA  France   NaN
# 2  1994-07-17    1898-08-13     1898.0         Average   FRA  France   NaN
# 3  1978-03-20    1895-05-11     1895.0         Average   FRA  France   NaN
# 4  1930-07-25    1878-04-17     1878.0            Tall   GBR      UK   NaN

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts().tail(25)
# Out:
# born_region
# Utah              91
# Missouri          91
# North Carolina    86
# Arizona           83
# New Hampshire     83
# Vermont           68
# Mississippi       66
# Alabama           64
# Kentucky          62
# Tennessee         62
# Nebraska          60
# Rhode Island      56
# Montana           55
# South Carolina    50
# Maine             50
# Alaska            45
# Arkansas          42
# Idaho             41
# New Mexico        38
# Nevada            36
# South Dakota      27
# West Virginia     24
# Delaware          22
# North Dakota      16
# Wyoming           14
# Name: count, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    230.0
# Latte       190.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type','Day']).agg({'Units Sold' : 'sum', 'price':'mean'})
# Out:
#                        Units Sold  price
# Coffee Type Day
# Espresso    Friday           45.0   3.99
#             Monday           25.0   3.99
#             Saturday         45.0   3.99
#             Sunday           45.0   3.99
#             Thursday         40.0   3.99
#             Tuesday          10.0   3.99
#             Wednesday        20.0   3.99
# Latte       Friday           35.0   5.99
#             Monday           15.0   5.99
#             Saturday         35.0   5.99
#             Sunday           35.0   5.99
#             Thursday         30.0   5.99
#             Tuesday          15.0   5.99
#             Wednesday        25.0   5.99

# %%
pivot = coffee.pivot(columns = 'Coffee Type', index='Day', values='revenue')
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   89.85
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday         39.90  119.80
# Wednesday      139.65  149.75
