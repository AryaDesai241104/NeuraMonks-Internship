# %% [markdown]
# ## LangChain day - 10 : Tools ,Tool Calling & Agents

# %% [markdown]
# ## What is a Tool?
# A tool is just a Python function (or API) that is packaged in a way the LLM can understand and call when needed.
#
# **LLMs (like GPT) are great at:**
# * Reasoning (Think)
# * Language generation
#
# **But they can’t do things like:**
# * Access live data (weather, news)
# * Do reliable math
# * Call APIs
# * Run code
# * Interact with a database

# %% [markdown]
# ### Types of tools
# 1. Built-in Tools
# 2. Custom Tools

# %% [markdown]
# ### How Tools fits into the Agent ecosystem
# An AI agent is an LLM-powered system that can autonomously think, decide, and take actions using external tools or APIs to achieve a goal.
#
# * **Agent** (The outer system)
#     * **Reasoning & Decision Making (LLM)**
#         * This core thinking process is powered by the **LLM**.
#     * **Action (Tools)**
#         * The ability to perform actions is enabled by **Tools**.

# %% [markdown]
# ### Built-in Tools
# A built-in tool is a tool that LangChain already provides for you — it’s pre-built, production-ready, and requires minimal or no setup.
# <br>You don’t have to write the function logic yourself — you just import and use it.
#
# Few tools are :
# * `DuckDuckGoSearchRun`: Web search via DuckDuckGo
# * `WikipediaQueryRun`: Wikipedia summary
# * `PythonREPLTool`: Run raw Python code
# * `ShellTool`: Run shell commands
# * `RequestsGetTool`: Make HTTP GET requests
# * `GmailSendMessageTool`: Send emails via Gmail
# * `SlackSendMessageTool`: Post message to Slack
# * `SQLDatabaseQueryTool`: Run SQL queries

# %% [markdown]
# ### Built-in-Tool - DuckDuckGO Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
results = search_tool.invoke('USA vs India')
print(results)
# Out:
# C:\Users\aryad\anaconda3\envs\tf_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:63: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# 5 days ago · India News: Donald Trump's administration has escalated trade tensions with India, imposing tariffs due to energy ties with Russia and stalled trade negotiations. Aug 7, 2025 · US Tariff on India: Trump imposed an additional 25% Tariff on Indian goods. Check the list of goods, tariff rates on products, and products that are exempted from tariff, impact on … Aug 6, 2025 · The US has increased tariffs on Indian exports to 50%, citing India's Russian oil purchases as a concern. This places India among the highest-tariffed nations US President … Aug 7, 2025 · The simmering India vs US tariff war has erupted with President Trump’s administration slapping a staggering cumulative 50% tariff on a wide range of Indian goods, … Aug 8, 2025 · After imposing a total of 50 per cent tariffs on India, Trump has now ruled out a possibility of holding negotiations on a potential trade deal. This marks a new low in India-US ties

# %% [markdown]
# ### Built-in-Tool - Shell Tool

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
results = shell_tool.invoke('dir')
print(results)
# Out:
# Executing command:
#  dir
#  Volume in drive C is Windows
